# %% [markdown]
# # Introdução:
#
# A ideia deste _notebook_ é entender como Python pode ser usado para análise de dados financeiros (em particular, dados de ações), implementar um algoritmo de LSTM para tentar fazer previsões em cima dos dados e ver como se saem essas previsões.
#
#
#
# # Preliminares:
# Começamos importando as bibliotecas a serem usadas, bem como os dados.
#
# Os dados, em arquivo `.csv`, foram obtidos da página: `https://www.infomoney.com.br/cotacoes/b3/bdr/nubank-nubr33/historico/`
#
# PS: Ao iniciar este _notebook_, eu ainda não sabia que poderia usar `yfinance` para importar dados melhor formatados e atualizados. Entretanto, trabalhar com este `.csv` foi bom para praticar o pré-processamento de dados, e por este motivo não fiz alterações neste sentido.

# %%
import datetime
import pandas            as pd
import numpy             as np
import matplotlib.pyplot as plt
import seaborn           as sns
from   tensorflow.keras.models     import Sequential
from   tensorflow.keras.optimizers import Adam
from   tensorflow.keras            import layers

# preparando a  exibição gráfica:
# %matplotlib inline
sns.set()           

# importando os dados:
nubank = pd.read_csv('nubr33.csv')

#---------#    alternativamente:    #-----------------# 
#-----------------------------------------------------#
# import yfinance as yf                               #
# t0 = pd.to_datetime('2023-01-01')                   #
# t1 = pd.to_datetime('now')                          #
# nubank = yf.download('NUBR33.SA', start=t0, end=t1) #
#-----------------------------------------------------#

nubank
# Out:
#            DATA ABERTURA FECHAMENTO VARIAÇÃO MÍNIMO MÁXIMO   VOLUME
# 0    26/07/2023     6,12       6,15     0,65   6,04   6,22   12,10M
# 1    25/07/2023     6,13       6,11    -0,65   6,11   6,29   15,51M
# 2    24/07/2023     6,20       6,15    -2,23   6,09   6,28   11,58M
# 3    21/07/2023     6,04       6,29     3,28   6,04   6,29   16,99M
# 4    20/07/2023     6,00       6,09     1,00   5,91   6,18   17,38M
# ..          ...      ...        ...      ...    ...    ...      ...
# 403  14/12/2021    10,64       9,25   -13,15   8,91  10,64   71,37M
# 404  13/12/2021    11,66      10,65    -7,39  10,35  11,90  135,65M
# 405  10/12/2021    10,34      11,50    14,54  10,06  11,73  206,69M
# 406  09/12/2021    10,18      10,04    20,10   9,40  10,20   51,43M
# 407  08/12/2021      n/d       8,36      n/d    n/d    n/d      n/d
#
# [408 rows x 7 columns]

# %%
# formata a string se livrando de vírgulas e convertendo as unidades de medida (K e M);
# converte string para numpy.float64;
def string_to_num(x):
  if x == "n/d":
    return np.nan
  elif x[-3] == ",":
    return np.float64(x[:-3]+"."+x[-2:])
  elif x[-4] == ",":
    if (x[-1] == "K"):
      return np.float64(x[:-4]+"."+x[-3:-1]) * (10**3)
    elif (x[-1] == "M"):
      return (np.float64(x[:-4]+"."+x[-3:-1]))*(10**6)

# %% [markdown]
# # Pré-Processamento de dados
#
# Verificamos se não há dados nulos e então renomeamos as colunas para nomes mais convenientes, nos livrando de letras maiúsculas e de caracteres indesejados.
#
# Depois, formatamos e convertemos a data para um tipo mais adequado, organizamos as linhas em ordem cronológica e definimos a coluna de data como índice.
#
# Os dados das colunas de `'ABERTURA'` até `'VOLUME'` são do tipo `str`, e a conversão para `numpy.float64` é inevitável, já que necessitamos efetuar cálculos sobre estes valores.

# %%
nubank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DATA        408 non-null    object
#  1   ABERTURA    408 non-null    object
#  2   FECHAMENTO  408 non-null    object
#  3   VARIAÇÃO    408 non-null    object
#  4   MÍNIMO      408 non-null    object
#  5   MÁXIMO      408 non-null    object
#  6   VOLUME      408 non-null    object
# dtypes: object(7)
# memory usage: 22.4+ KB

# %%
# renomeando as colunas:
nubank.rename(columns = {'VARIAÇÃO':'variacao', 'MÍNIMO':'min', 'MÁXIMO':'max'}, inplace=True)
nubank.columns = nubank.columns.str.lower()

# formatando e convertendo a data:
nubank['data'] = nubank['data'].apply(lambda x: x[-4:] + "-" + x[3:5] + "-" + x[0:2])
nubank['data'] = pd.to_datetime(nubank['data'])

# reindexando e reordenando o dataframe:
nubank.set_index('data', inplace=True)
nubank.sort_index(ascending=True, inplace=True)

# convertendo os dados das colunas de 'abertura' até 'max'
for column in nubank.columns[:]:
  nubank[column] = nubank[column].apply(string_to_num)

#------#
nubank # dataset após o pré-processamento.
#------#
# Out:
#             abertura  fechamento  variacao    min    max       volume
# data
# 2021-12-08       NaN        8.36       NaN    NaN    NaN          NaN
# 2021-12-09     10.18       10.04     20.10   9.40  10.20   51430000.0
# 2021-12-10     10.34       11.50     14.54  10.06  11.73  206690000.0
# 2021-12-13     11.66       10.65     -7.39  10.35  11.90  135650000.0
# 2021-12-14     10.64        9.25    -13.15   8.91  10.64   71370000.0
# ...              ...         ...       ...    ...    ...          ...
# 2023-07-20      6.00        6.09      1.00   5.91   6.18   17380000.0
# 2023-07-21      6.04        6.29      3.28   6.04   6.29   16990000.0
# 2023-07-24      6.20        6.15     -2.23   6.09   6.28   11580000.0
# 2023-07-25      6.13        6.11     -0.65   6.11   6.29   15510000.0
# 2023-07-26      6.12        6.15      0.65   6.04   6.22   12100000.0
#
# [408 rows x 6 columns]

# %% [markdown]
# # Análise
# Agora, podemos começar a investigar melhor os dados. Iniciamos olhando para os dados referentes ao presente ano (2023).

# %%
ano2023 = (nubank.index >= '2023')
nubank[ano2023].describe()
# Out:
#          abertura  fechamento    variacao         min         max
# count  142.000000  142.000000  142.000000  142.000000  142.000000  \
# mean     4.624155    4.643732    0.440423    4.536972    4.748169
# std      1.070308    1.075703    2.994097    1.061707    1.079940
# min      3.050000    3.040000   -8.440000    2.970000    3.100000
# 25%      3.802500    3.820000   -1.287500    3.732500    3.922500
# 50%      4.200000    4.225000    0.525000    4.100000    4.330000
# 75%      5.727500    5.740000    2.167500    5.617500    5.817500
# max      6.520000    6.530000   10.360000    6.300000    6.600000
#
#              volume
# count  1.420000e+02
# mean   2.023148e+07
# std    1.394006e+07
# min    1.890000e+06
# 25%    1.099250e+07
# 50%    1.649000e+07
# 75%    2.503500e+07
# max    7.827000e+07

# %% [markdown]
# Vemos que a média de ```fechamento``` é ligeiramente maior do que a média de ```abertura```, e que a média de ```variacao``` é positiva, o que nos diz que as ações mais subiram do que desceram no ano de 2023 até o momento. Abaixo, plotamos um gráfico para observar o comportamento da ação ao longo dos dias.

# %%
nubank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 408 entries, 2021-12-08 to 2023-07-26
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   abertura    407 non-null    float64
#  1   fechamento  408 non-null    float64
#  2   variacao    407 non-null    float64
#  3   min         407 non-null    float64
#  4   max         407 non-null    float64
#  5   volume      407 non-null    float64
# dtypes: float64(6)
# memory usage: 22.3 KB

# %%
fig1 = plt.figure(figsize=(8,3), dpi=100)

axes1 = fig1.add_axes([0, 0, 1, 1])
axes1.plot(nubank[ano2023]['fechamento'], 'y', label='fechamento')
axes1.set_ylabel('Valor (R$)')
axes1.legend(loc=0)

# %% [markdown]
# # Média Móvel
#
# A crescente no período analisado é visível. Para melhor entendê-la, calculamos a média móvel dos valores de fechamento para períodos de 6, 28 e 64 dias, e as introduzimos como colunas em nosso dataframe:

# %%
nubank['mm6']   =  nubank['fechamento'].rolling(window=6).mean()
nubank['mm28']  =  nubank['fechamento'].rolling(window=28).mean()
nubank['mm64']  =  nubank['fechamento'].rolling(window=64).mean()
nubank[ano2023]
# Out:
#             abertura  fechamento  variacao   min   max      volume       mm6
# data
# 2023-01-02      3.51        3.39     -3.42  3.39  3.53   5590000.0  3.381667  \
# 2023-01-03      3.45        3.18     -6.19  3.17  3.55  27900000.0  3.353333
# 2023-01-04      3.23        3.13     -1.57  3.13  3.29   7390000.0  3.326667
# 2023-01-05      3.18        3.09     -1.28  3.06  3.19  11780000.0  3.283333
# 2023-01-06      3.09        3.05     -1.29  2.97  3.16  17620000.0  3.225000
# ...              ...         ...       ...   ...   ...         ...       ...
# 2023-07-20      6.00        6.09      1.00  5.91  6.18  17380000.0  6.193333
# 2023-07-21      6.04        6.29      3.28  6.04  6.29  16990000.0  6.153333
# 2023-07-24      6.20        6.15     -2.23  6.09  6.28  11580000.0  6.150000
# 2023-07-25      6.13        6.11     -0.65  6.11  6.29  15510000.0  6.128333
# 2023-07-26      6.12        6.15      0.65  6.04  6.22  12100000.0  6.136667
#
#                 mm28      mm64
# data
# 2023-01-02  3.516071  3.757344
# 2023-01-03  3.490714  3.745469
# 2023-01-04  3.463571  3.732656
# 2023-01-05  3.433929  3.717500
# 2023-01-06  3.408214  3.699844
# ...              ...       ...
# 2023-07-20  6.167500  5.536406
# 2023-07-21  6.175714  5.572031
# 2023-07-24  6.185714  5.604375
# 2023-07-25  6.191429  5.635938
# 2023-07-26  6.197857  5.668281
#
# [142 rows x 9 columns]

# %%
fig = plt.figure(figsize=(5,4), dpi=100)
ax  = fig.add_axes([0.1, 0.1, 1.6, 1])

ax.plot(nubank[ano2023]['mm6'])
ax.plot(nubank[ano2023]['mm28'])
ax.plot(nubank[ano2023]['mm64'])
ax.plot(nubank[ano2023]['fechamento'])
ax.legend(['mm6','mm28','mm64','fechamento'])

# %% [markdown]
# # Previsão LSTM:
#
#
# Vamos, inicialmente, tentar fazer uma previsão simples para o valor de fechamento. Para isso, consideramos apenas a seguinte coluna:

# %%
fechamento =  nubank['fechamento']
fig        =  plt.figure(figsize=(14,8), dpi=100)

plt.plot(fechamento)

# %% [markdown]
# E agora construímos uma função para gerar uma tabela com alvos por data:

# %%
def df_alvos(df, n):

  '''
  Recebe um dataframe de uma coluna indexada por datas
  e retorna um dataframe cujas linhas são compostas
  por uma data, seguida pelos n valores anteriores à data e,
  por fim, o valor referente à data que inicia a linha.
  '''

  df = df.reset_index()

  nomes = ['data_alvo']
  for i in range(1, n+1):
    nomes.append("x_"+str(n-i+1))
  nomes.append('alvo')

  novo_df=[]
  for i in range(n, len(df)):
    novo_df.append([df[df.columns[0]][i]])
    for j in range(0, n+1):
      novo_df[i-n].append(df[df.columns[1]][i-(n-j)])

  return pd.DataFrame(novo_df, columns=nomes)

# %% [markdown]
# Repare, na tabela abaixo, que `alvo` é o valor de fechamento das ações em um dado dia, `x_1` é o fechamento 1 dia antes, `x_2` é o fechamento 2 dias antes, e assim por diante:

# %%
pred = 7

df_alvos(fechamento, pred)
# Out:
#      data_alvo    x_7    x_6    x_5    x_4   x_3   x_2   x_1  alvo
# 0   2021-12-17   8.36  10.04  11.50  10.65  9.25  9.54  9.49  8.95
# 1   2021-12-20  10.04  11.50  10.65   9.25  9.54  9.49  8.95  8.50
# 2   2021-12-21  11.50  10.65   9.25   9.54  9.49  8.95  8.50  8.70
# 3   2021-12-22  10.65   9.25   9.54   9.49  8.95  8.50  8.70  8.54
# 4   2021-12-23   9.25   9.54   9.49   8.95  8.50  8.70  8.54  9.20
# ..         ...    ...    ...    ...    ...   ...   ...   ...   ...
# 396 2023-07-20   6.33   6.28   6.53   6.17  6.24  6.10  6.03  6.09
# 397 2023-07-21   6.28   6.53   6.17   6.24  6.10  6.03  6.09  6.29
# 398 2023-07-24   6.53   6.17   6.24   6.10  6.03  6.09  6.29  6.15
# 399 2023-07-25   6.17   6.24   6.10   6.03  6.09  6.29  6.15  6.11
# 400 2023-07-26   6.24   6.10   6.03   6.09  6.29  6.15  6.11  6.15
#
# [401 rows x 9 columns]

# %% [markdown]
# Agora, separamos os alvos das datas, e os transformamos:

# %%
def df_alvos_separados(alvos):
  '''
  Separa o dataframe de alvos em um numpy.ndarray
  de datas, um de variáveis ind
  '''
  alvos_np = alvos.to_numpy()

  datas = alvos_np[:, 0]
  Y = alvos_np[:, -1]

  meiuca = alvos_np[:, 1:-1]
  X = meiuca.reshape((len(datas), meiuca.shape[1], 1))

  return datas, X.astype(np.float32), Y.astype(np.float32)

# %%
datas, x, y = df_alvos_separados(df_alvos(fechamento, pred))

# %%
q_80 = int(len(datas)*0.8)
q_90 = int(len(datas)*0.9)

datas_treino, x_treino, y_treino = datas[:q_80],     x[:q_80],     y[:q_80]
datas_val,    x_val,    y_val    = datas[q_80:q_90], x[q_80:q_90], y[q_80:q_90]
datas_teste,  x_teste,  y_teste  = datas[q_90:],     x[q_90:],     y[q_90:]

# %% [markdown]
# Agora, podemos visualizar os conjuntos de treino, teste e validação da nossa variável dependente y:

# %%
fig = plt.figure(figsize=(5,4), dpi=100)

axe = fig.add_axes([0.1, 0.1, 1.6, 1])
axe.plot(datas_treino, y_treino)
axe.plot(datas_val, y_val)
axe.plot(datas_teste, y_teste)

# %%
# aqui, nós criamos e treinamos a rede neural
model = Sequential([layers.Input((pred,1)),
                    layers.LSTM(128),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(x_treino, y_treino, validation_data=(x_val, y_val), epochs=128)
# Out:
# Epoch 1/128
# 2023-07-27 16:20:21.749538: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-27 16:20:21.752435: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-27 16:20:21.754229: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-07-27 16:20:22.142615: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-27 16:20:22.144520: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-27 16:20:22.145925: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-07-27 16:20:22.868717: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-27 16:20:22.870618: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-27 16:20:22.872057: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 10/10 [==============================] - 2s 65ms/step - loss: 14.0682 - mean_absolute_error: 3.3881 - val_loss: 2.0212 - val_mean_absolute_error: 1.3362
# Epoch 2/128
# 2023-07-27 16:20:24.188471: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-27 16:20:24.190252: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-27 16:20:24.191547: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 10/10 [==============================] - 0s 12ms/step - loss: 2.5403 - mean_absolute_error: 1.2948 - val_loss: 1.2224 - val_mean_absolute_error: 1.0144
# Epoch 3/128
# 10/10 [==============================] - 0s 12ms/step - loss: 1.6108 - mean_absolute_error: 0.8874 - val_loss: 0.4612 - val_mean_absolute_error: 0.5450
# Epoch 4/128
# 10/10 [==============================] - 0s 11ms/step - loss: 1.1622 - mean_absolute_error: 0.7707 - val_loss: 0.2988 - val_mean_absolute_error: 0.4702
# Epoch 5/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.5603 - mean_absolute_error: 0.5300 - val_loss: 0.0809 - val_mean_absolute_error: 0.2396
# Epoch 6/128
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2212 - mean_absolute_error: 0.3216 - val_loss: 0.0227 - val_mean_absolute_error: 0.1229
# Epoch 7/128
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1539 - mean_absolute_error: 0.2820 - val_loss: 0.0442 - val_mean_absolute_error: 0.1750
# Epoch 8/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1485 - mean_absolute_error: 0.2838 - val_loss: 0.0377 - val_mean_absolute_error: 0.1622
# Epoch 9/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1370 - mean_absolute_error: 0.2658 - val_loss: 0.0376 - val_mean_absolute_error: 0.1608
# Epoch 10/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1239 - mean_absolute_error: 0.2545 - val_loss: 0.0860 - val_mean_absolute_error: 0.2547
# Epoch 11/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1280 - mean_absolute_error: 0.2525 - val_loss: 0.0386 - val_mean_absolute_error: 0.1626
# Epoch 12/128
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1227 - mean_absolute_error: 0.2441 - val_loss: 0.0730 - val_mean_absolute_error: 0.2329
# Epoch 13/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1205 - mean_absolute_error: 0.2440 - val_loss: 0.0616 - val_mean_absolute_error: 0.2116
# Epoch 14/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1162 - mean_absolute_error: 0.2368 - val_loss: 0.0354 - val_mean_absolute_error: 0.1545
# Epoch 15/128
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1192 - mean_absolute_error: 0.2375 - val_loss: 0.0377 - val_mean_absolute_error: 0.1600
# Epoch 16/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1163 - mean_absolute_error: 0.2395 - val_loss: 0.0600 - val_mean_absolute_error: 0.2085
# Epoch 17/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1248 - mean_absolute_error: 0.2463 - val_loss: 0.0787 - val_mean_absolute_error: 0.2432
# Epoch 18/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1176 - mean_absolute_error: 0.2407 - val_loss: 0.0582 - val_mean_absolute_error: 0.2048
# Epoch 19/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1145 - mean_absolute_error: 0.2397 - val_loss: 0.0570 - val_mean_absolute_error: 0.2025
# Epoch 20/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1208 - mean_absolute_error: 0.2441 - val_loss: 0.0549 - val_mean_absolute_error: 0.1978
# Epoch 21/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1053 - mean_absolute_error: 0.2280 - val_loss: 0.0645 - val_mean_absolute_error: 0.2173
# Epoch 22/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1146 - mean_absolute_error: 0.2301 - val_loss: 0.0793 - val_mean_absolute_error: 0.2446
# Epoch 23/128
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1041 - mean_absolute_error: 0.2218 - val_loss: 0.0349 - val_mean_absolute_error: 0.1536
# Epoch 24/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1015 - mean_absolute_error: 0.2166 - val_loss: 0.0639 - val_mean_absolute_error: 0.2166
# Epoch 25/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1063 - mean_absolute_error: 0.2176 - val_loss: 0.0314 - val_mean_absolute_error: 0.1439
# Epoch 26/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1026 - mean_absolute_error: 0.2189 - val_loss: 0.0373 - val_mean_absolute_error: 0.1591
# Epoch 27/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0995 - mean_absolute_error: 0.2155 - val_loss: 0.0624 - val_mean_absolute_error: 0.2140
# Epoch 28/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1020 - mean_absolute_error: 0.2144 - val_loss: 0.0257 - val_mean_absolute_error: 0.1271
# Epoch 29/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1050 - mean_absolute_error: 0.2244 - val_loss: 0.0288 - val_mean_absolute_error: 0.1288
# Epoch 30/128
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1203 - mean_absolute_error: 0.2440 - val_loss: 0.0321 - val_mean_absolute_error: 0.1453
# Epoch 31/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1016 - mean_absolute_error: 0.2224 - val_loss: 0.0309 - val_mean_absolute_error: 0.1421
# Epoch 32/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.1047 - mean_absolute_error: 0.2234 - val_loss: 0.0790 - val_mean_absolute_error: 0.2446
# Epoch 33/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1067 - mean_absolute_error: 0.2242 - val_loss: 0.0315 - val_mean_absolute_error: 0.1436
# Epoch 34/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1068 - mean_absolute_error: 0.2335 - val_loss: 0.0342 - val_mean_absolute_error: 0.1505
# Epoch 35/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1229 - mean_absolute_error: 0.2523 - val_loss: 0.0252 - val_mean_absolute_error: 0.1190
# Epoch 36/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1271 - mean_absolute_error: 0.2586 - val_loss: 0.0262 - val_mean_absolute_error: 0.1217
# Epoch 37/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1292 - mean_absolute_error: 0.2554 - val_loss: 0.0228 - val_mean_absolute_error: 0.1135
# Epoch 38/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.1034 - mean_absolute_error: 0.2223 - val_loss: 0.0384 - val_mean_absolute_error: 0.1606
# Epoch 39/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0982 - mean_absolute_error: 0.2123 - val_loss: 0.0448 - val_mean_absolute_error: 0.1761
# Epoch 40/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0921 - mean_absolute_error: 0.2046 - val_loss: 0.0313 - val_mean_absolute_error: 0.1425
# Epoch 41/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1006 - mean_absolute_error: 0.2177 - val_loss: 0.0231 - val_mean_absolute_error: 0.1143
# Epoch 42/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0977 - mean_absolute_error: 0.2166 - val_loss: 0.0211 - val_mean_absolute_error: 0.1113
# Epoch 43/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.1006 - mean_absolute_error: 0.2128 - val_loss: 0.0379 - val_mean_absolute_error: 0.1590
# Epoch 44/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0883 - mean_absolute_error: 0.2025 - val_loss: 0.0597 - val_mean_absolute_error: 0.2096
# Epoch 45/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0995 - mean_absolute_error: 0.2190 - val_loss: 0.0583 - val_mean_absolute_error: 0.2066
# Epoch 46/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1021 - mean_absolute_error: 0.2188 - val_loss: 0.0343 - val_mean_absolute_error: 0.1498
# Epoch 47/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0888 - mean_absolute_error: 0.2013 - val_loss: 0.0225 - val_mean_absolute_error: 0.1173
# Epoch 48/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0867 - mean_absolute_error: 0.2003 - val_loss: 0.0521 - val_mean_absolute_error: 0.1937
# Epoch 49/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0886 - mean_absolute_error: 0.2056 - val_loss: 0.0291 - val_mean_absolute_error: 0.1354
# Epoch 50/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0826 - mean_absolute_error: 0.1938 - val_loss: 0.0204 - val_mean_absolute_error: 0.1088
# Epoch 51/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0937 - mean_absolute_error: 0.2153 - val_loss: 0.0314 - val_mean_absolute_error: 0.1415
# Epoch 52/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0855 - mean_absolute_error: 0.1966 - val_loss: 0.0382 - val_mean_absolute_error: 0.1598
# Epoch 53/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0864 - mean_absolute_error: 0.1993 - val_loss: 0.0198 - val_mean_absolute_error: 0.1087
# Epoch 54/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0873 - mean_absolute_error: 0.2023 - val_loss: 0.0292 - val_mean_absolute_error: 0.1353
# Epoch 55/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0816 - mean_absolute_error: 0.1909 - val_loss: 0.0194 - val_mean_absolute_error: 0.1075
# Epoch 56/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0839 - mean_absolute_error: 0.1951 - val_loss: 0.0263 - val_mean_absolute_error: 0.1262
# Epoch 57/128
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0849 - mean_absolute_error: 0.1939 - val_loss: 0.0488 - val_mean_absolute_error: 0.1859
# Epoch 58/128
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0942 - mean_absolute_error: 0.2188 - val_loss: 0.0755 - val_mean_absolute_error: 0.2391
# Epoch 59/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.1134 - mean_absolute_error: 0.2439 - val_loss: 0.0717 - val_mean_absolute_error: 0.2323
# Epoch 60/128
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0956 - mean_absolute_error: 0.2115 - val_loss: 0.0193 - val_mean_absolute_error: 0.1069
# Epoch 61/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0868 - mean_absolute_error: 0.2005 - val_loss: 0.0205 - val_mean_absolute_error: 0.1099
# Epoch 62/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0840 - mean_absolute_error: 0.2012 - val_loss: 0.0194 - val_mean_absolute_error: 0.1070
# Epoch 63/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0815 - mean_absolute_error: 0.1951 - val_loss: 0.0201 - val_mean_absolute_error: 0.1083
# Epoch 64/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0790 - mean_absolute_error: 0.1932 - val_loss: 0.0255 - val_mean_absolute_error: 0.1227
# Epoch 65/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0828 - mean_absolute_error: 0.1932 - val_loss: 0.0192 - val_mean_absolute_error: 0.1057
# Epoch 66/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0839 - mean_absolute_error: 0.2012 - val_loss: 0.0261 - val_mean_absolute_error: 0.1244
# Epoch 67/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0862 - mean_absolute_error: 0.2037 - val_loss: 0.0522 - val_mean_absolute_error: 0.1938
# Epoch 68/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0830 - mean_absolute_error: 0.1955 - val_loss: 0.0453 - val_mean_absolute_error: 0.1776
# Epoch 69/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0883 - mean_absolute_error: 0.2040 - val_loss: 0.0525 - val_mean_absolute_error: 0.1942
# Epoch 70/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0769 - mean_absolute_error: 0.1903 - val_loss: 0.0530 - val_mean_absolute_error: 0.1950
# Epoch 71/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0807 - mean_absolute_error: 0.1985 - val_loss: 0.0462 - val_mean_absolute_error: 0.1796
# Epoch 72/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0784 - mean_absolute_error: 0.1937 - val_loss: 0.0393 - val_mean_absolute_error: 0.1624
# Epoch 73/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0755 - mean_absolute_error: 0.1876 - val_loss: 0.0386 - val_mean_absolute_error: 0.1604
# Epoch 74/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0768 - mean_absolute_error: 0.1863 - val_loss: 0.0192 - val_mean_absolute_error: 0.1045
# Epoch 75/128
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0777 - mean_absolute_error: 0.1919 - val_loss: 0.0200 - val_mean_absolute_error: 0.1052
# Epoch 76/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0786 - mean_absolute_error: 0.1951 - val_loss: 0.0314 - val_mean_absolute_error: 0.1398
# Epoch 77/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0881 - mean_absolute_error: 0.2120 - val_loss: 0.0547 - val_mean_absolute_error: 0.1983
# Epoch 78/128
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0758 - mean_absolute_error: 0.1939 - val_loss: 0.0211 - val_mean_absolute_error: 0.1083
# Epoch 79/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0746 - mean_absolute_error: 0.1859 - val_loss: 0.0185 - val_mean_absolute_error: 0.1057
# Epoch 80/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0918 - mean_absolute_error: 0.2133 - val_loss: 0.0276 - val_mean_absolute_error: 0.1282
# Epoch 81/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1004 - mean_absolute_error: 0.2359 - val_loss: 0.0438 - val_mean_absolute_error: 0.1725
# Epoch 82/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0906 - mean_absolute_error: 0.2096 - val_loss: 0.0572 - val_mean_absolute_error: 0.2033
# Epoch 83/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0890 - mean_absolute_error: 0.2154 - val_loss: 0.0437 - val_mean_absolute_error: 0.1725
# Epoch 84/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0846 - mean_absolute_error: 0.2018 - val_loss: 0.0802 - val_mean_absolute_error: 0.2487
# Epoch 85/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0770 - mean_absolute_error: 0.1934 - val_loss: 0.0353 - val_mean_absolute_error: 0.1497
# Epoch 86/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0708 - mean_absolute_error: 0.1830 - val_loss: 0.0185 - val_mean_absolute_error: 0.1050
# Epoch 87/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0699 - mean_absolute_error: 0.1822 - val_loss: 0.0332 - val_mean_absolute_error: 0.1437
# Epoch 88/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0716 - mean_absolute_error: 0.1835 - val_loss: 0.0202 - val_mean_absolute_error: 0.1051
# Epoch 89/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0705 - mean_absolute_error: 0.1860 - val_loss: 0.0402 - val_mean_absolute_error: 0.1625
# Epoch 90/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0759 - mean_absolute_error: 0.1869 - val_loss: 0.0207 - val_mean_absolute_error: 0.1068
# Epoch 91/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0711 - mean_absolute_error: 0.1816 - val_loss: 0.0232 - val_mean_absolute_error: 0.1133
# Epoch 92/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0720 - mean_absolute_error: 0.1856 - val_loss: 0.0245 - val_mean_absolute_error: 0.1167
# Epoch 93/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0716 - mean_absolute_error: 0.1853 - val_loss: 0.0286 - val_mean_absolute_error: 0.1292
# Epoch 94/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0688 - mean_absolute_error: 0.1810 - val_loss: 0.0199 - val_mean_absolute_error: 0.1118
# Epoch 95/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0825 - mean_absolute_error: 0.1995 - val_loss: 0.0184 - val_mean_absolute_error: 0.1073
# Epoch 96/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0805 - mean_absolute_error: 0.2007 - val_loss: 0.0212 - val_mean_absolute_error: 0.1078
# Epoch 97/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0671 - mean_absolute_error: 0.1759 - val_loss: 0.0181 - val_mean_absolute_error: 0.1034
# Epoch 98/128
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0728 - mean_absolute_error: 0.1882 - val_loss: 0.0182 - val_mean_absolute_error: 0.1039
# Epoch 99/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0724 - mean_absolute_error: 0.1855 - val_loss: 0.0188 - val_mean_absolute_error: 0.1095
# Epoch 100/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0866 - mean_absolute_error: 0.2134 - val_loss: 0.0362 - val_mean_absolute_error: 0.1617
# Epoch 101/128
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0870 - mean_absolute_error: 0.2119 - val_loss: 0.0179 - val_mean_absolute_error: 0.1042
# Epoch 102/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0733 - mean_absolute_error: 0.1927 - val_loss: 0.0237 - val_mean_absolute_error: 0.1141
# Epoch 103/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0724 - mean_absolute_error: 0.1893 - val_loss: 0.0398 - val_mean_absolute_error: 0.1594
# Epoch 104/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0713 - mean_absolute_error: 0.1788 - val_loss: 0.0494 - val_mean_absolute_error: 0.1839
# Epoch 105/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0789 - mean_absolute_error: 0.1990 - val_loss: 0.0342 - val_mean_absolute_error: 0.1434
# Epoch 106/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0695 - mean_absolute_error: 0.1949 - val_loss: 0.0482 - val_mean_absolute_error: 0.1812
# Epoch 107/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0845 - mean_absolute_error: 0.2108 - val_loss: 0.0391 - val_mean_absolute_error: 0.1571
# Epoch 108/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0932 - mean_absolute_error: 0.2203 - val_loss: 0.0184 - val_mean_absolute_error: 0.1071
# Epoch 109/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0843 - mean_absolute_error: 0.2090 - val_loss: 0.0202 - val_mean_absolute_error: 0.1143
# Epoch 110/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0738 - mean_absolute_error: 0.1929 - val_loss: 0.0246 - val_mean_absolute_error: 0.1166
# Epoch 111/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0705 - mean_absolute_error: 0.1888 - val_loss: 0.0257 - val_mean_absolute_error: 0.1195
# Epoch 112/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0675 - mean_absolute_error: 0.1809 - val_loss: 0.0193 - val_mean_absolute_error: 0.1055
# Epoch 113/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0658 - mean_absolute_error: 0.1796 - val_loss: 0.0256 - val_mean_absolute_error: 0.1190
# Epoch 114/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0837 - mean_absolute_error: 0.2062 - val_loss: 0.0613 - val_mean_absolute_error: 0.2119
# Epoch 115/128
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0757 - mean_absolute_error: 0.1937 - val_loss: 0.0204 - val_mean_absolute_error: 0.1076
# Epoch 116/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0677 - mean_absolute_error: 0.1800 - val_loss: 0.0204 - val_mean_absolute_error: 0.1075
# Epoch 117/128
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0652 - mean_absolute_error: 0.1768 - val_loss: 0.0221 - val_mean_absolute_error: 0.1106
# Epoch 118/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0677 - mean_absolute_error: 0.1863 - val_loss: 0.0243 - val_mean_absolute_error: 0.1286
# Epoch 119/128
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0766 - mean_absolute_error: 0.1993 - val_loss: 0.0181 - val_mean_absolute_error: 0.1057
# Epoch 120/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0669 - mean_absolute_error: 0.1828 - val_loss: 0.0183 - val_mean_absolute_error: 0.1079
# Epoch 121/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0736 - mean_absolute_error: 0.1841 - val_loss: 0.0182 - val_mean_absolute_error: 0.1069
# Epoch 122/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0640 - mean_absolute_error: 0.1775 - val_loss: 0.0365 - val_mean_absolute_error: 0.1484
# Epoch 123/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0657 - mean_absolute_error: 0.1764 - val_loss: 0.0230 - val_mean_absolute_error: 0.1132
# Epoch 124/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0670 - mean_absolute_error: 0.1818 - val_loss: 0.0183 - val_mean_absolute_error: 0.1071
# Epoch 125/128
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0668 - mean_absolute_error: 0.1828 - val_loss: 0.0184 - val_mean_absolute_error: 0.1046
# Epoch 126/128
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0680 - mean_absolute_error: 0.1831 - val_loss: 0.0195 - val_mean_absolute_error: 0.1065
# Epoch 127/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0690 - mean_absolute_error: 0.1840 - val_loss: 0.0243 - val_mean_absolute_error: 0.1163
# Epoch 128/128
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0671 - mean_absolute_error: 0.1771 - val_loss: 0.0271 - val_mean_absolute_error: 0.1225

# %%
train_predictions = model.predict(x_treino).flatten()


fig = plt.figure(figsize=(5,4), dpi=100)
axe = fig.add_axes([0.1, 0.1, 1.6, 1])

axe.plot(datas_treino, train_predictions)
axe.plot(datas_treino, y_treino)
axe.legend(['pedricoes de treino', 'observacoes de treino'])
# Out:
# 10/10 [==============================] - 0s 4ms/step
# 2023-07-27 16:20:39.720330: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-27 16:20:39.722223: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-27 16:20:39.723570: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
val_predictions = model.predict(x_val).flatten()


fig = plt.figure(figsize=(5,4), dpi=100)
axe = fig.add_axes([0.1, 0.1, 1.6, 1])

axe.plot(datas_val, val_predictions)
axe.plot(datas_val, y_val)
axe.legend(['pedricoes de validacao', 'observacoes de validacao'])
# Out:
# 2/2 [==============================] - 0s 6ms/step
# 2023-07-27 16:20:44.870307: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-27 16:20:44.872756: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-27 16:20:44.874267: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
test_predictions = model.predict(x_teste).flatten()


fig = plt.figure(figsize=(5,4), dpi=100)
axe = fig.add_axes([0.1, 0.1, 1.6, 1])

axe.plot(datas_teste, test_predictions)
axe.plot(datas_teste, y_teste)
axe.legend(['pedricoes de teste', 'observacoes de teste'])
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
print("erro máximo:\t", np.max(abs(test_predictions - y_teste)))
print("erro médio:\t", np.mean(abs(test_predictions - y_teste)))

# %%
from copy import deepcopy

predicao_recursiva = []
data_recursiva = np.concatenate([datas_val, datas_teste])

for target in data_recursiva:
  ultimo = deepcopy(x_treino[-1])
  proximo = model.predict(np.array([ultimo])).flatten()
  predicao_recursiva.append(proximo)
  ultimo[-1] = proximo
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
fig = plt.figure(figsize=(5,4), dpi=100)
axe = fig.add_axes([0.1, 0.1, 2.8, 2])


axe.plot(datas_treino, train_predictions)
axe.plot(datas_treino, y_treino)
axe.plot(datas_val, val_predictions)
axe.plot(datas_val, y_val)
axe.plot(datas_teste, test_predictions)
axe.plot(datas_teste, y_teste)
axe.plot(data_recursiva, predicao_recursiva)
axe.legend(['predicao treino',
            'observação trein',
            'predicao validacao',
            'observvação validação',
            'predição teste',
            'observação teste',
            'predição recursiva'])

# %% [markdown]
# # Conclusão
#
# Mais cuidados poderiam ser tomados ao implementar o modelo de LSTM, porém, observando que o modelo fez uma previsão de preços constantes de fechamento de uma ação, temos um forte indicativo de que o uso de LSTM não é uma alternativa viável para prever preços de ações.
